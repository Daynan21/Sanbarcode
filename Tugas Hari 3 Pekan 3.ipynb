# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2>Soal 1: Multiple Subplots</h2>
#
# Dengan data di bawah ini buatlah visualisasi seperti expected output:

# %%
x = np.linspace(2*-np.pi, 2*np.pi, 200)
tan = np.tan(x)/10
cos = np.cos(x)
sin = np.sin(x)

# %%
# code here
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(2*-np.pi, 2*np.pi, 200)
tan = np.tan(x)/10
cos = np.cos(x)
sin = np.sin(x)
fig, ax = plt.subplots(ncols=3, figsize=(20,8),sharex=True, sharey=True)
ax[0].plot(x, tan, color='b', label='tanX')
ax[0].set_title('Grafik tanx')
ax[1].plot(x, cos, color='r', label='sinX')
ax[1].set_title('Grafik sinx')
ax[2].plot(x, sin, color='g', label='cosX')
ax[2].set_title('Grafik cosx')
fig.legend(loc='upper center')
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xdrkV37TJk7isPQIjg9gNJ6capaCLYam)

# %% [markdown]
# <h2>Soal 2: Nested Axis</h2>
#
# Dengan data di bawah ini, buatlah visualisasi seperti expected output:

# %%
x = np.linspace(2*-np.pi, 2*np.pi, 100)
y = np.cos(x)
y2 = np.cos(x**2)
y3 = np.cos(x**3)
y4 = np.cos(x**4)
y5 = np.cos(x**5)

# %%
# code here
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(2*-np.pi, 2*np.pi, 100)
y = np.cos(x)
y2 = np.cos(x**2)
y3 = np.cos(x**3)
y4 = np.cos(x**4)
y5 = np.cos(x**5)
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(x, y, color='blue')
ax.set_title('Grafik CosX')
ins1= ax.inset_axes([0.8, 0.8, 0.4, 0.4])
ins1.plot(x, y, color='blue')
ins1.plot(x, y4, color='black')
ins1.set_title('Grafik CosX^4')
ins2= ax.inset_axes([-0.1, -0.1, 0.4, 0.4])
ins2.plot(x, y, color='blue')
ins2.plot(x, y2, color='red')
ins2.set_title('Grafik CosX^2')
ins3= ax.inset_axes([-0.1, 0.8, 0.4, 0.4])
ins3.plot(x, y, color='blue')
ins3.plot(x, y5, color='yellow')
ins3.set_title('Grafik CosX^5')
ins4= ax.inset_axes([0.8, -0.1, 0.4, 0.4])
ins4.plot(x, y, color='blue')
ins4.plot(x, y3, color='green')
ins4.set_title('Grafik CosX^3')
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xIdrYVaafiMdAP59fyMkxZ-qwxapAD_g)
